# %%
import pandas as pd
import glob

# %%
files = glob.glob('../data/processed_weather/varginha/*.csv')

dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

df_weather = pd.concat(dfs, ignore_index=True)

# %%
df_weather['datetime'] = pd.to_datetime(df_weather['datetime'])
df_weather = df_weather.sort_values('datetime')

df_weather = df_weather.drop_duplicates(subset='datetime')

df_weather.to_csv("../data/weather.csv", index=False)
df_weather
# Out:
#        datetime  chuva       temp  temp_max  temp_min    umidade
# 3653 2012-01-01   27.2  20.016667      22.7      19.1  95.833333
# 3654 2012-01-02   22.6  19.829167      23.9      17.8  92.916667
# 3655 2012-01-03    0.4  21.462500      28.2      17.5  79.666667
# 3656 2012-01-04    0.0  22.187500      29.3      15.9  67.416667
# 3657 2012-01-05    0.0  22.341667      29.5      15.5  66.708333
# ...         ...    ...        ...       ...       ...        ...
# 4744 2025-12-27    0.0        NaN       NaN       NaN        NaN
# 4745 2025-12-28    0.0        NaN       NaN       NaN        NaN
# 4746 2025-12-29    0.0        NaN       NaN       NaN        NaN
# 4747 2025-12-30    0.0        NaN       NaN       NaN        NaN
# 4748 2025-12-31    0.0        NaN       NaN       NaN        NaN
#
# [5114 rows x 6 columns]
